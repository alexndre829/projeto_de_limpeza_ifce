# %% [markdown]
# <a href="https://colab.research.google.com/github/alexndre829/projeto_de_limpeza_ifce/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

soma = num1 + num2
subtracao = num1 - num2
multiplicacao = num1 * num2
divisao = num1 / num2 if num2 != 0 else "Erro: divisão por zero"

print(f"Soma: {soma}")
print(f"Subtração: {subtracao}")
print(f"Multiplicação: {multiplicacao}")
print(f"Divisão: {divisao}")

print("\n" + "="*50 + "\n")
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 7
# Soma: 11.0
# Subtração: -3.0
# Multiplicação: 28.0
# Divisão: 0.5714285714285714
#
# ...
